# %% [markdown]
# Variables and data types

# %%
name = "Rahul"

# %%
print(name)
# Out:
# Rahul

# %%
type(name)
# Out:
# str

# %%
name = 1
print(name)
type(name)
# Out:
# 1
# int

# %%
ls
# Out:
# sample_data/

# %%
j=3

# %% [markdown]
# # Arithmatic Operation

# %%
a=5
b=2
c = a + b
print("a:" + a)
print(b)
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-a9ee37650ffd> in <cell line: 4>()
#       2 b=2
#       3 c = a + b
# ----> 4 print("a:" + a)
#       5 print(b)
#       6 print(c)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a=5
b=2
c = a + b
print("a:", a)
print(b)
print(c)
# Out:
# a: 5
# 2
# 7

# %%
a * b
# Out:
# 10

# %%
b = a**2
print(b)
# Out:
# 25

# %%
b = a**3
print(b)

# %% [markdown]
# # Conditioning and Looping

# %%
age = 15
if age >= 18:
  print("you can vote")
else:
  print("you cannot vote")
# Out:
# you cannot vote

# %%
age = 18
if age >= 18:
  print("you can vote")
elif age == 17:
  print("you can almost vote")
else:
  print("you cannot vote")
# Out:
# you can vote

# %% [markdown]
# # For Loop

# %%
  for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1, 5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# # while loop

# %%
i = 0
while i < 5:
  print (i)
  i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # Working with methods

# %%
def add(a, b):
  return a + b

add(3,4)
# Out:
# 7

# %%
sum = add(5,6)

print(sum)
# Out:
# 11

# %%
def display():
  i = 0
  while i < 5:
    print (i)
    i += 1
display()
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # List and Dictionary

# %%
name1 = "Rahul"
name2 = "John"

nameList = [name1, name2]

type(nameList)
# Out:
# list

# %%
print(nameList)
# Out:
# ['Rahul', 'John']

# %%
contact = 999999

employeeList = [name1, name2, contact]

type(employeeList)
# Out:
# list

# %%
print(employeeList)
# Out:
# ['Rahul', 'John', 999999]

# %%
print(employeeList[0])
# Out:
# Rahul

# %%
print(employeeList[1:3])
# Out:
# ['John', 999999]

# %%
employeeList [1] = "Kumar"

# %%
print(employeeList)
# Out:
# ['Rahul', 'Kumar', 999999]

# %%
len(employeeList)
# Out:
# 3

# %%
employeeListCopy = list(employeeList)

# %%
employeeListCopy[0] = "Jack"

# %%
mergedList = employeeList + employeeListCopy
print(mergedList)
# Out:
# ['Rahul', 'Kumar', 999999, 'Jack', 'Kumar', 999999]

# %% [markdown]
# # Dictionary and tuple and set
